# %%
from IPython.display import display, HTML
import style_utils as style_config

# %%
white_text = "Using numpy, finding the top words is simply \n sorting the average values for each row, and taking the top N."
html_output = '<span class="spark-nlp-display-others" style="background-color: white">{}</span>'.format(white_text)

html_output += '<span class="spark-nlp-display-entity-wrapper" style="background-color: {}"><span class="spark-nlp-display-entity-name">{} </span><span class="spark-nlp-display-entity-type">{}</span></span>'.format(
                    "#555",
                    "numpy",
                    "test")


html_output += """</div>"""

html_output = html_output.replace("\n", "<br>")

html_content_save = style_config.STYLE_CONFIG_ENTITIES+ " "+html_output

display(HTML(html_content_save))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .spark-nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .spark-nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .spark-nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         color: #000000 ;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .spark-nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
# ...

# %%
text = """„Stunde der Wintervögel“: Mehr Waldvögel in Gärten zu Gast
Mehr Waldvögel und mehr Amseln: Für die Zählaktion „Stunde der Wintervögel“ hat der Landesbund für Vogelschutz (LBV) erste Zwischenergebnisse für Bayern veröffentlicht. Bürgerinnen und Bürger, die bis zum vergangenen Sonntag Vögel im Garten, am Balkon oder im Park gezählt haben, beobachteten in diesem Jahr auffällig viele Waldvögel wie Buntspecht, Kleiber oder Gimpel.
Hilpoltstein - Dass sie sich vermehrt in Siedlungsgebieten aufhielten, könne mehrere Ursachen haben, teilte der LBV am Montag mit. Finden die Vögel in den Wäldern nicht genug Nahrung, treibt sie die Futtersuche in besiedelte Gebiete. Ein vorübergehender Zuzug aus kälteren Regionen könnte den Zuwachs ebenfalls erklären. „Diese Beobachtungen stimmen auch mit der neuesten wissenschaftlichen Übersicht der Bestandssituation der Vögel in Deutschland überein, in der sich eine deutliche Erholung der Vogelbestände im Wald abzeichnet“, sagte LBV-Expertin Angelika Nelson.
Zudem wurden auch wieder mehr Amseln beobachtet - nachdem diese Vogelart durch das vermehrte Auftreten von Erkrankungen durch die aus Afrika stammenden Usutu-Viren geschwächt war. „Die positive Entwicklung ist vielleicht ein Zeichen dafür, dass die Folgen des Usutu-Virus überwunden sind“, sagte Nelson.
Am häufigsten registriert wurden bei der Zählaktion Haussperlinge vor den Kohlmeisen. Der LBV im bayerischen Hilpoltstein und der Naturschutzbund Deutschland (Nabu) in Berlin haben zum zwölften Mal zu der nach ihren Angaben größten wissenschaftlichen Mitmachaktion Deutschlands aufgerufen. Noch bis zum 17. Januar können die Menschen ihre Beobachtungen melden. Im vergangenen Jahr hatten sich nach Nabu-Angaben mehr als 236.000 Menschen bundesweit beteiligt. dpa"""
print(text)
# Out:
# „Stunde der Wintervögel“: Mehr Waldvögel in Gärten zu Gast
# Mehr Waldvögel und mehr Amseln: Für die Zählaktion „Stunde der Wintervögel“ hat der Landesbund für Vogelschutz (LBV) erste Zwischenergebnisse für Bayern veröffentlicht. Bürgerinnen und Bürger, die bis zum vergangenen Sonntag Vögel im Garten, am Balkon oder im Park gezählt haben, beobachteten in diesem Jahr auffällig viele Waldvögel wie Buntspecht, Kleiber oder Gimpel.
# ...

# %%
entity_list = [{'entity_count': '0',
  'token': 'Waldvögel',
  'entity': 'CONSUMER_GOOD',
  'begin_end_offset': [31, 40],
  'salience': 0.09189999848604202},
 {'entity_count': '1',
  'token': 'Waldvögel',
  'entity': 'CONSUMER_GOOD',
  'begin_end_offset': [64, 73],
  'salience': 0.09189999848604202},
 {'entity_count': '2',
  'token': 'Vogelschutz',
  'entity': 'OTHER',
  'begin_end_offset': [158, 169],
  'salience': 0.08160000294446945},
 {'entity_count': '3',
  'token': 'Zählaktion',
  'entity': 'OTHER',
  'begin_end_offset': [99, 109],
  'salience': 0.06989999860525131},
 {'entity_count': '4',
  'token': 'Amseln',
  'entity': 'OTHER',
  'begin_end_offset': [83, 89],
  'salience': 0.06989999860525131}]

# %%
sorted(entity_list, key=lambda x:x["begin_end_offset"][0])
# Out:
# [{'entity_count': '0',
#   'token': 'Waldvögel',
#   'entity': 'CONSUMER_GOOD',
#   'begin_end_offset': [31, 40],
#   'salience': 0.09189999848604202},
#  {'entity_count': '1',
#   'token': 'Waldvögel',
#   'entity': 'CONSUMER_GOOD',
#   'begin_end_offset': [64, 73],
#   'salience': 0.09189999848604202},
#  {'entity_count': '4',
#   'token': 'Amseln',
#   'entity': 'OTHER',
#   'begin_end_offset': [83, 89],
#   'salience': 0.06989999860525131},
#  {'entity_count': '3',
#   'token': 'Zählaktion',
#   'entity': 'OTHER',
#   'begin_end_offset': [99, 109],
#   'salience': 0.06989999860525131},
#  {'entity_count': '2',
#   'token': 'Vogelschutz',
#   'entity': 'OTHER',
#   'begin_end_offset': [158, 169],
#   'salience': 0.08160000294446945}]

# %%
white_text = "Using numpy, finding the top words is simply \n sorting the average values for each row, and taking the top N."
html_output = '<span class="spark-nlp-display-others" style="background-color: white">{}</span>'.format(white_text)

html_output += '<span class="spark-nlp-display-entity-wrapper" style="background-color: {}"><span class="spark-nlp-display-entity-name">{} </span><span class="spark-nlp-display-entity-type">{}</span></span>'.format(
                    "#555",
                    "numpy",
                    "test")


html_output += """</div>"""

html_output = html_output.replace("\n", "<br>")

html_content_save = style_config.STYLE_CONFIG_ENTITIES+ " "+html_output

display(HTML(html_content_save))

# %%
import json
path = "/Users/aydin/Documents/Ippen/projects/ner-prepro/code/raw_data/kg_ner_data-10_000.json"

with open(path, 'r') as json_file:
    data = json.load(json_file)

len(data)
# Out:
# 10000

# %%
data["0"]
# Out:
# {'ner_results': [{'entity_count': '0',
#    'token': 'Vertrag',
#    'entity': 'OTHER',
#    'begin_end_offset': [22, 29],
#    'salience': 0.19189999997615814},
#   {'entity_count': '1',
#    'token': 'Schlittschuhläufer',
#    'entity': 'PERSON',
#    'begin_end_offset': [41, 59],
#    'salience': 0.1436000019311905},
#   {'entity_count': '2',
#    'token': 'Vertrag',
#    'entity': 'OTHER',
#    'begin_end_offset': [130, 137],
#    'salience': 0.12470000237226486},
#   {'entity_count': '3',
#    'token': 'Ingolstadt',
#    'entity': 'LOCATION',
#    'begin_end_offset': [0, 10],
#    'salience': 0.06920000165700912},
#   {'entity_count': '4',
#    'token': 'Schlittschuhläufer',
#    'entity': 'PERSON',
#    'begin_end_offset': [197, 215],
#    'salience': 0.06040000170469284},
#   {'entity_count': '5',
#    'token': 'Storm',
#    'entity': 'WORK_OF_ART',
#    'begin_end_offset': [61, 66],
#    'salience': 0.05550000071525574},
#   {'entity_count': '6',
# ...

# %%
sorted(entity_list[0:20], key=lambda x:x["begin_end_offset"][0])
# Out:
# [{'entity_count': '10',
#   'token': 'POL-DO',
#   'entity': 'OTHER',
#   'begin_end_offset': [0, 6],
#   'salience': 0.025200000032782555},
#  {'entity_count': '11',
#   'token': 'Happy End',
#   'entity': 'OTHER',
#   'begin_end_offset': [17, 26],
#   'salience': 0.025200000032782555},
#  {'entity_count': '1',
#   'token': 'Autodiebstahls',
#   'entity': 'OTHER',
#   'begin_end_offset': [33, 47],
#   'salience': 0.12189999967813492},
#  {'entity_count': '3',
#   'token': 'Tatverdächtige',
#   'entity': 'PERSON',
#   'begin_end_offset': [49, 63],
#   'salience': 0.08139999955892563},
#  {'entity_count': '2',
#   'token': 'Polizei',
#   'entity': 'ORGANIZATION',
#   'begin_end_offset': [82, 89],
#   'salience': 0.11249999701976776},
#  {'entity_count': '7',
#   'token': 'Dortmund',
#   'entity': 'LOCATION',
#   'begin_end_offset': [90, 98],
#   'salience': 0.033399999141693115},
#  {'entity_count': '12',
#   'token': 'POL-DO',
#   'entity': 'ORGANIZATION',
# ...

# %%
color_dict = {"CONSUMER_GOOD":"#800000",
    "OTHER":"#800080", "LOCATION":"#000080",'PERSON':"#808000",
    'WORK_OF_ART':"#808080",'ORGANIZATION':"#0000FF",'DATE': "#808080",
    'EVENT':"#808000",'PHONE_NUMBER':"#808080"}
i = 0
new_text = ""
idx = str(500)
entity_list = data[idx]['ner_results']
text = data[idx]['meta']['text']
for item in sorted(entity_list[0:10], key=lambda x:x["begin_end_offset"][0]):
    if i == 0:
        white_begin = 0
        if item["begin_end_offset"][0] > 0:
            white_end = item["begin_end_offset"][0]-1
        else:
            white_end = 0
        white_text = text[white_begin:white_end]
        html_output = '<span class="nlp-display-others" style="background-color: white">{}</span>'.format(white_text)
        #new_text += white_text+item["token"]
        lab = item['entity'] + " - score "+str(round(item['salience']*100))+" - idx "+item['entity_count']
        html_output += '<span class="nlp-display-entity-wrapper" style="background-color: {}"><span class="nlp-display-entity-name">{} </span><span class="nlp-display-entity-type">{}</span></span>'.format(
                    color_dict[item['entity']],
                    item['token'],
                    lab)
        white_begin = item["begin_end_offset"][1]
        i +=1
    else:
        white_end = item["begin_end_offset"][0]-1
        white_text = text[white_begin:white_end]
        html_output += '<span class="nlp-display-others" style="background-color: white">{}</span>'.format(white_text)
        #new_text += text[white_begin:white_end]+" "+item["token"]
        lab = item['entity'] + " - score "+str(round(item['salience']*100))+" - idx "+item['entity_count']
        html_output += '<span class="nlp-display-entity-wrapper" style="background-color: {}"><span class="nlp-display-entity-name">{} </span><span class="nlp-display-entity-type">{}</span></span>'.format(
                    color_dict[item['entity']],
                    item['token'],
                    lab)
        white_begin = item["begin_end_offset"][1]

white_text = text[white_begin:len(text)]
html_output += '<span class="nlp-display-others" style="background-color: white">{}</span>'.format(white_text)

html_output += """</div>"""

html_output = html_output.replace("\n", "<br>")

html_content_save = style_config.STYLE_CONFIG_ENTITIES+ " "+html_output

display(HTML(html_content_save))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700&display=swap');
#     @import url('https://fonts.googleapis.com/css2?family=Vistol Regular:wght@300;400;500;600;700&display=swap');
#
#     .nlp-display-scroll-entities {
#         border: 1px solid #E7EDF0;
#         border-radius: 3px;
#         text-align: justify;
#
#     }
#     .nlp-display-scroll-entities span {
#         font-size: 14px;
#         line-height: 24px;
#         color: #536B76;
#         font-family: 'Montserrat', sans-serif !important;
#     }
#
#     .nlp-display-entity-wrapper{
#
#         display: inline-grid;
#         text-align: center;
#         border-radius: 4px;
#         color: #000000 ;
#         margin: 0 2px 5px 2px;
#         padding: 1px
#     }
#     .nlp-display-entity-name{
#         font-size: 14px;
#         line-height: 24px;
#         font-family: 'Montserrat', sans-serif !important;
#
#         background: #f1f2f3;
# ...
